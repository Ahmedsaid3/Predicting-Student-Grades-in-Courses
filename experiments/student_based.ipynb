# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import recommendations
from sklearn.cluster import KMeans

# %%
df = pd.read_csv("./processed_data.csv")

# %%
df.head()
# Out:
#    Student Number                                       Course Title  \
# 0               0  Ideological and Moral Cultivation and Legal Fo...
# 1               0                           Success: Career Planning
# 2               0                   Introduction to Computer Science
# 3               0                          Advanced Mathematics A(1)
# 4               0                               College English A(1)
#
#    Course Credit  Grades  Course Semester       GPA  Completed Credits  \
# 0            2.5       4                1  3.102564               19.5
# 1            1.0       3                1  3.102564               19.5
# 2            2.0       1                1  3.102564               19.5
# 3            5.5       4                1  3.102564               19.5
# 4            4.0       3                1  3.102564               19.5
#
#    Semester GPA  Semester Credit Department Code
# 0      3.102564             19.5             BLG
# 1      3.102564             19.5             BLG
# 2      3.102564             19.5             BLG
# 3      3.102564             19.5             BLG
# 4      3.102564             19.5             BLG

# %%
df
# Out:
#        Student Number                                       Course Title  \
# 0                   0  Ideological and Moral Cultivation and Legal Fo...
# 1                   0                           Success: Career Planning
# 2                   0                   Introduction to Computer Science
# 3                   0                          Advanced Mathematics A(1)
# 4                   0                               College English A(1)
# ...               ...                                                ...
# 19095             381                                     J2EE Framework
# 19096             381      Intellectual Property and Software Protection
# 19097             381              Human-Computer Interaction Technology
# 19098             381          Software Development and Testing Training
# 19099             381                        Python Language Programming
#
#        Course Credit  Grades  Course Semester       GPA  Completed Credits  \
# 0                2.5       4                1  3.102564               19.5
# 1                1.0       3                1  3.102564               19.5
# 2                2.0       1                1  3.102564               19.5
# 3                5.5       4                1  3.102564               19.5
# 4                4.0       3                1  3.102564               19.5
# ...              ...     ...              ...       ...                ...
# 19095            4.5       3                6  2.790076              131.0
# 19096            1.0       4                7  2.838129              139.0
# 19097            2.0       5                7  2.838129              139.0
# 19098            3.0       3                7  2.838129              139.0
# 19099            2.0       3                7  2.838129              139.0
#
#        Semester GPA  Semester Credit
# 0          3.102564             19.5
# 1          3.102564             19.5
# 2          3.102564             19.5
# 3          3.102564             19.5
# 4          3.102564             19.5
# ...             ...              ...
# 19095      2.800000             20.0
# 19096      3.625000              8.0
# 19097      3.625000              8.0
# 19098      3.625000              8.0
# 19099      3.625000              8.0
#
# [19100 rows x 9 columns]

# %%
df = pd.concat([df, pd.get_dummies(df['Department Code'], prefix='Department Code')], axis=1)
df.drop(['Department Code'], axis=1, inplace=True)

# %%
df
# Out:
#        Student Number                                       Course Title  \
# 0                   0  Ideological and Moral Cultivation and Legal Fo...
# 1                   0                           Success: Career Planning
# 2                   0                   Introduction to Computer Science
# 3                   0                          Advanced Mathematics A(1)
# 4                   0                               College English A(1)
# ...               ...                                                ...
# 19095             381                                     J2EE Framework
# 19096             381      Intellectual Property and Software Protection
# 19097             381              Human-Computer Interaction Technology
# 19098             381          Software Development and Testing Training
# 19099             381                        Python Language Programming
#
#        Course Credit  Grades  Course Semester       GPA  Completed Credits  \
# 0                2.5       4                1  3.102564               19.5
# 1                1.0       3                1  3.102564               19.5
# 2                2.0       1                1  3.102564               19.5
# 3                5.5       4                1  3.102564               19.5
# 4                4.0       3                1  3.102564               19.5
# ...              ...     ...              ...       ...                ...
# 19095            4.5       3                6  2.790076              131.0
# 19096            1.0       4                7  2.838129              139.0
# 19097            2.0       5                7  2.838129              139.0
# 19098            3.0       3                7  2.838129              139.0
# 19099            2.0       3                7  2.838129              139.0
#
#        Semester GPA  Semester Credit  Department Code_BLG
# 0          3.102564             19.5                    1
# 1          3.102564             19.5                    1
# 2          3.102564             19.5                    1
# 3          3.102564             19.5                    1
# 4          3.102564             19.5                    1
# ...             ...              ...                  ...
# 19095      2.800000             20.0                    1
# 19096      3.625000              8.0                    1
# 19097      3.625000              8.0                    1
# 19098      3.625000              8.0                    1
# 19099      3.625000              8.0                    1
#
# [19100 rows x 10 columns]

# %%
course_credits = {}
for row_idx in df.index:
    course_title = df.iloc[row_idx, 1]
    credit = df.iloc[row_idx, 2]    
    course_credits[course_title] = credit

# %%
def get_semester_data(semester_num):
    semester_data = {}   # semester data in shape {student_number: {course_title: grade, ...}, ...}
    
    # extracting the instances with the given semester_num from the main dataFrame
    dataset = df[df.iloc[:, 4] == semester_num]
    dataset.index = range(len(dataset))
    
    # ~ burda column numaralarini uyarladik 

    # filling the semester_data dictionary
    for row_idx in dataset.index:
        student_number = dataset.iloc[row_idx, 0]
        course_title = dataset.iloc[row_idx, 1]
        grade = dataset.iloc[row_idx, 3]
        
        semester_data.setdefault(student_number, {})
        semester_data[student_number][course_title] = grade
    
    return semester_data

# %%
get_semester_data(1)
# Out:
# {0: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 1,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 3,
#   'University Chinese': 1,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 3},
#  1: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 1,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 3,
#   'University Chinese': 2,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 5},
#  2: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 2,
#   'College English A(1)': 2,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 3},
#  3: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 2,
#   'College English A(1)': 2,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 3},
#  4: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 3,
#   'College English A(1)': 3,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 3},
#  5: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 4,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 3},
#  6: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 2,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 3},
#  7: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 2,
#   'College English A(1)': 3,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 4},
#  8: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 5,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 2,
#   'University Chinese': 5,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 3},
#  9: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 3,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 3},
#  10: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 3,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 3},
#  11: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 2,
#   'College English A(1)': 2,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 3},
#  12: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 3,
#   'College English A(1)': 2,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 3},
#  13: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 3,
#   'College English A(1)': 2,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 3},
#  14: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 2,
#   'Advanced Mathematics A(1)': 2,
#   'College English A(1)': 3,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 3},
#  15: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 1,
#   'College English A(1)': 2,
#   'University Chinese': 2,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 3},
#  16: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 3,
#   'College English A(1)': 2,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 3},
#  17: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 1,
#   'College English A(1)': 2,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 5},
#  18: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 3,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 5},
#  19: {'Ideological and Moral Cultivation and Legal Foundation': 5,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 3,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 5},
#  20: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 2,
#   'College English A(1)': 2,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 5},
#  21: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 5,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 4,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 5},
#  22: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 3,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 5},
#  23: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 2,
#   'College English A(1)': 4,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 3},
#  24: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 4,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 5},
#  25: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 2,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 4},
#  26: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 3,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 4},
#  27: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 2,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 4},
#  28: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 3,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 4},
#  29: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 2,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 4},
#  30: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 2,
#   'College English A(1)': 2,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 4},
#  31: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 3,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 4},
#  32: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 2,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 4},
#  33: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 2,
#   'Advanced Mathematics A(1)': 2,
#   'College English A(1)': 2,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 5},
#  34: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 2,
#   'College English A(1)': 2,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 5},
#  35: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 2,
#   'College English A(1)': 2,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 5},
#  36: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 5,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 2,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 5},
#  37: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 2,
#   'Advanced Mathematics A(1)': 2,
#   'College English A(1)': 2,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 5},
#  38: {'Ideological and Moral Cultivation and Legal Foundation': 5,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 1,
#   'University Chinese': 1,
#   'Mental Health Education for College Students': 1,
#   'Ideological and Political Theory Course Practice1': 1},
#  39: {'Ideological and Moral Cultivation and Legal Foundation': 5,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 2,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 5},
#  40: {'Ideological and Moral Cultivation and Legal Foundation': 5,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 5,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 4,
#   'University Chinese': 5,
#   'Mental Health Education for College Students': 5,
#   'Ideological and Political Theory Course Practice1': 5},
#  41: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 2,
#   'Advanced Mathematics A(1)': 1,
#   'College English A(1)': 4,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 5},
#  42: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 3,
#   'College English A(1)': 4,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 5},
#  43: {'Ideological and Moral Cultivation and Legal Foundation': 5,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 3,
#   'College English A(1)': 3,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 5},
#  44: {'Ideological and Moral Cultivation and Legal Foundation': 5,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 5,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 3,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 5,
#   'Ideological and Political Theory Course Practice1': 5},
#  45: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 2,
#   'Advanced Mathematics A(1)': 1,
#   'College English A(1)': 3,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 5},
#  46: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 3,
#   'College English A(1)': 2,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 5,
#   'Ideological and Political Theory Course Practice1': 5},
#  47: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 2,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 5,
#   'Ideological and Political Theory Course Practice1': 5},
#  48: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 2,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 5},
#  49: {'Ideological and Moral Cultivation and Legal Foundation': 5,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 3,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 5},
#  50: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 2,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 5},
#  51: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 3,
#   'College English A(1)': 3,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 5},
#  52: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 2,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 5},
#  53: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 3,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 5},
#  54: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 2,
#   'College English A(1)': 2,
#   'University Chinese': 2,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 5},
#  55: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 3,
#   'College English A(1)': 2,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 5,
#   'Ideological and Political Theory Course Practice1': 3},
#  56: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 3,
#   'College English A(1)': 3,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 5},
#  57: {'Ideological and Moral Cultivation and Legal Foundation': 5,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 5,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 3,
#   'University Chinese': 5,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 5},
#  58: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 2,
#   'College English A(1)': 2,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 5},
#  59: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 4,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 3},
#  60: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 2,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 2,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 3},
#  61: {'Ideological and Moral Cultivation and Legal Foundation': 5,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 4,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 5,
#   'Ideological and Political Theory Course Practice1': 5},
#  62: {'Ideological and Moral Cultivation and Legal Foundation': 5,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 3,
#   'University Chinese': 5,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 5},
#  63: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 5,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 2,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 5},
#  64: {'Ideological and Moral Cultivation and Legal Foundation': 5,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 4,
#   'University Chinese': 5,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 5},
#  65: {'Ideological and Moral Cultivation and Legal Foundation': 5,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 4,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 5,
#   'Ideological and Political Theory Course Practice1': 5},
#  66: {'Ideological and Moral Cultivation and Legal Foundation': 5,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 1,
#   'College English A(1)': 4,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 5},
#  67: {'Ideological and Moral Cultivation and Legal Foundation': 5,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 2,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 5},
#  68: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 3,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 5},
#  69: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 4,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 5},
#  70: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 5,
#   'Advanced Mathematics A(1)': 2,
#   'College English A(1)': 2,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 5},
#  71: {'Ideological and Moral Cultivation and Legal Foundation': 5,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 3,
#   'College English A(1)': 3,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 5},
#  72: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 2,
#   'College English A(1)': 3,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 5,
#   'Ideological and Political Theory Course Practice1': 5},
#  73: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 3,
#   'College English A(1)': 4,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 5},
#  74: {'Ideological and Moral Cultivation and Legal Foundation': 5,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 3,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 5},
#  75: {'Ideological and Moral Cultivation and Legal Foundation': 5,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 5,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 3,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 5},
#  76: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 3,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 5},
#  77: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 2,
#   'Advanced Mathematics A(1)': 3,
#   'College English A(1)': 3,
#   'University Chinese': 2,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 5},
#  78: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 2,
#   'College English A(1)': 2,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 5,
#   'Ideological and Political Theory Course Practice1': 5},
#  79: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 2,
#   'Advanced Mathematics A(1)': 1,
#   'College English A(1)': 2,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 5},
#  80: {'Ideological and Moral Cultivation and Legal Foundation': 5,
#   'Success: Career Planning': 1,
#   'Introduction to Computer Science': 1,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 3,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 5,
#   'Ideological and Political Theory Course Practice1': 2},
#  81: {'Ideological and Moral Cultivation and Legal Foundation': 2,
#   'Success: Career Planning': 5,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 3,
#   'University Chinese': 2,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 2},
#  82: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 2,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 2},
#  83: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 3,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 2},
#  84: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 5,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 2,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 2},
#  85: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 5,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 3,
#   'College English A(1)': 3,
#   'University Chinese': 2,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 2},
#  86: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 3,
#   'College English A(1)': 2,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 2},
#  87: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 5,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 3,
#   'College English A(1)': 4,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 5,
#   'Ideological and Political Theory Course Practice1': 2},
#  88: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 5,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 3,
#   'University Chinese': 2,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 2},
#  89: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 5,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 3,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 2},
#  90: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 5,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 2,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 2},
#  91: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 5,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 2,
#   'College English A(1)': 4,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 2},
#  92: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 3,
#   'College English A(1)': 3,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 2},
#  93: {'Ideological and Moral Cultivation and Legal Foundation': 2,
#   'Success: Career Planning': 5,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 4,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 2},
#  94: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 5,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 3,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 2},
#  95: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 3,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 2},
#  96: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 1,
#   'College English A(1)': 3,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 2},
#  97: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 5,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 3,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 2},
#  98: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 5,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 2},
#  99: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 5,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 3,
#   'College English A(1)': 4,
#   'University Chinese': 2,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 2},
#  100: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 3,
#   'College English A(1)': 1,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 2},
#  101: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 5,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 1,
#   'College English A(1)': 1,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 2},
#  102: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 3,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 5,
#   'Ideological and Political Theory Course Practice1': 2},
#  103: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 5,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 3,
#   'College English A(1)': 4,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 2},
#  104: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 3,
#   'College English A(1)': 4,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 2},
#  105: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 5,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 3,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 2},
#  106: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 2,
#   'University Chinese': 5,
#   'Mental Health Education for College Students': 5,
#   'Ideological and Political Theory Course Practice1': 2},
#  107: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 5,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 3,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 2},
#  108: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 5,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 2,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 2},
#  109: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 5,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 1,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 2},
#  110: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 5,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 3,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 5,
#   'Ideological and Political Theory Course Practice1': 2},
#  111: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 5,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 3,
#   'College English A(1)': 4,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 2},
#  112: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 2,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 2},
#  113: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 5,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 3,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 5,
#   'Ideological and Political Theory Course Practice1': 2},
#  114: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 5,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 2,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 5,
#   'Ideological and Political Theory Course Practice1': 2},
#  115: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 5,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 3,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 2},
#  116: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 2,
#   'University Chinese': 2,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 2},
#  117: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 3,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 2},
#  118: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 5,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 3,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 2},
#  119: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 5,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 3,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 2},
#  120: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 5,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 2,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 2},
#  121: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 5,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 3,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 5,
#   'Ideological and Political Theory Course Practice1': 2},
#  122: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 5,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 4,
#   'University Chinese': 5,
#   'Mental Health Education for College Students': 5,
#   'Ideological and Political Theory Course Practice1': 2},
#  123: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 3,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 5,
#   'Ideological and Political Theory Course Practice1': 2},
#  124: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 2,
#   'College English A(1)': 2,
#   'University Chinese': 2,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 2},
#  125: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 3,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 2},
#  126: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 5,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 2,
#   'College English A(1)': 3,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 2},
#  127: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 5,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 3,
#   'University Chinese': 2,
#   'Mental Health Education for College Students': 5,
#   'Ideological and Political Theory Course Practice1': 2},
#  128: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 1,
#   'College English A(1)': 2,
#   'University Chinese': 1,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 2},
#  129: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 5,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 3,
#   'College English A(1)': 3,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 2},
#  130: {'Ideological and Moral Cultivation and Legal Foundation': 2,
#   'Success: Career Planning': 5,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 3,
#   'College English A(1)': 3,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 5,
#   'Ideological and Political Theory Course Practice1': 2},
#  131: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 5,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 2,
#   'College English A(1)': 3,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 2},
#  132: {'Ideological and Moral Cultivation and Legal Foundation': 2,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 2,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 5,
#   'Ideological and Political Theory Course Practice1': 2},
#  133: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 5,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 3,
#   'College English A(1)': 1,
#   'University Chinese': 2,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 2},
#  134: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 5,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 2,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 5,
#   'Ideological and Political Theory Course Practice1': 2},
#  135: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 5,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 1,
#   'College English A(1)': 4,
#   'University Chinese': 2,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 2},
#  136: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 1,
#   'College English A(1)': 4,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 2},
#  137: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 5,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 3,
#   'University Chinese': 5,
#   'Mental Health Education for College Students': 5,
#   'Ideological and Political Theory Course Practice1': 2},
#  138: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 5,
#   'Introduction to Computer Science': 5,
#   'Advanced Mathematics A(1)': 2,
#   'College English A(1)': 2,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 2},
#  139: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 5,
#   'Advanced Mathematics A(1)': 3,
#   'College English A(1)': 2,
#   'University Chinese': 2,
#   'Mental Health Education for College Students': 3,
# ...
#   'College English A(1)': 2,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 2},
#  336: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 2,
#   'Introduction to Computer Science': 2,
#   'Advanced Mathematics A(1)': 1,
#   'College English A(1)': 3,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 4},
#  337: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 2,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 2,
#   'College English A(1)': 2,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 4},
#  338: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 4,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 1,
#   'College English A(1)': 4,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 4},
#  339: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 4,
#   'Introduction to Computer Science': 2,
#   'Advanced Mathematics A(1)': 2,
#   'College English A(1)': 3,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 4},
#  340: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 2,
#   'Introduction to Computer Science': 2,
#   'Advanced Mathematics A(1)': 2,
#   'College English A(1)': 3,
#   'University Chinese': 2,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 4},
#  341: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 2,
#   'Introduction to Computer Science': 2,
#   'Advanced Mathematics A(1)': 3,
#   'College English A(1)': 3,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 2},
#  342: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 2,
#   'Introduction to Computer Science': 2,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 2,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 2},
#  343: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 4,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 2,
#   'College English A(1)': 3,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 2},
#  344: {'Ideological and Moral Cultivation and Legal Foundation': 5,
#   'Success: Career Planning': 2,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 2,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 5,
#   'Ideological and Political Theory Course Practice1': 5},
#  345: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 4,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 3,
#   'College English A(1)': 3,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 2},
#  346: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 2,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 1,
#   'College English A(1)': 2,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 4},
#  347: {'Ideological and Moral Cultivation and Legal Foundation': 5,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 2,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 3,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 4},
#  348: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 4,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 3,
#   'College English A(1)': 4,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 4},
#  349: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 4,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 1,
#   'College English A(1)': 3,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 4},
#  350: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 5,
#   'Introduction to Computer Science': 2,
#   'Advanced Mathematics A(1)': 2,
#   'College English A(1)': 2,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 4},
#  351: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 2,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 1,
#   'College English A(1)': 3,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 4},
#  352: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 2,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 3,
#   'College English A(1)': 2,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 4},
#  353: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 5,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 3,
#   'College English A(1)': 3,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 4},
#  354: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 2,
#   'Introduction to Computer Science': 2,
#   'Advanced Mathematics A(1)': 1,
#   'College English A(1)': 3,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 4},
#  355: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 4,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 1,
#   'College English A(1)': 4,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 4},
#  356: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 2,
#   'Introduction to Computer Science': 2,
#   'Advanced Mathematics A(1)': 1,
#   'College English A(1)': 4,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 4},
#  357: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 4,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 3,
#   'College English A(1)': 3,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 3},
#  358: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 2,
#   'Introduction to Computer Science': 2,
#   'Advanced Mathematics A(1)': 3,
#   'College English A(1)': 3,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 4},
#  359: {'Ideological and Moral Cultivation and Legal Foundation': 5,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 2,
#   'Advanced Mathematics A(1)': 3,
#   'College English A(1)': 3,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 4},
#  360: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 4,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 5,
#   'College English A(1)': 3,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 2},
#  361: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 2,
#   'Introduction to Computer Science': 2,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 4,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 4},
#  362: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 2,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 3,
#   'College English A(1)': 2,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 4},
#  363: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 2,
#   'Introduction to Computer Science': 4,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 1,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 4},
#  364: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 5,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 3,
#   'College English A(1)': 1,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 4},
#  365: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 2,
#   'Introduction to Computer Science': 2,
#   'Advanced Mathematics A(1)': 2,
#   'College English A(1)': 2,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 4},
#  366: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 2,
#   'Introduction to Computer Science': 2,
#   'Advanced Mathematics A(1)': 1,
#   'College English A(1)': 2,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 2},
#  367: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 2,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 2,
#   'College English A(1)': 1,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 4},
#  368: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 2,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 3,
#   'College English A(1)': 3,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 4},
#  369: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 2,
#   'Introduction to Computer Science': 2,
#   'Advanced Mathematics A(1)': 1,
#   'College English A(1)': 3,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 4},
#  370: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 2,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 2,
#   'College English A(1)': 2,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 4},
#  371: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 2,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 1,
#   'College English A(1)': 2,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 4},
#  372: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 5,
#   'Introduction to Computer Science': 2,
#   'Advanced Mathematics A(1)': 2,
#   'College English A(1)': 3,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 3},
#  373: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 2,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 1,
#   'College English A(1)': 4,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 4},
#  374: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#   'Success: Career Planning': 2,
#   'Introduction to Computer Science': 2,
#   'Advanced Mathematics A(1)': 1,
#   'College English A(1)': 3,
#   'University Chinese': 4,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 4},
#  375: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 2,
#   'Advanced Mathematics A(1)': 2,
#   'College English A(1)': 3,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 2},
#  376: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 2,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 3,
#   'College English A(1)': 2,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 3},
#  377: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 2,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 4,
#   'College English A(1)': 3,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 3},
#  378: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 3,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 3,
#   'College English A(1)': 3,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 4},
#  379: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 2,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 1,
#   'College English A(1)': 3,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 4},
#  380: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#   'Success: Career Planning': 5,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 1,
#   'College English A(1)': 4,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 3,
#   'Ideological and Political Theory Course Practice1': 4},
#  381: {'Ideological and Moral Cultivation and Legal Foundation': 5,
#   'Success: Career Planning': 4,
#   'Introduction to Computer Science': 3,
#   'Advanced Mathematics A(1)': 3,
#   'College English A(1)': 3,
#   'University Chinese': 3,
#   'Mental Health Education for College Students': 4,
#   'Ideological and Political Theory Course Practice1': 4}}

# %%
def get_avg_gpa(train_semester, student):
    courses = train_semester[student]
    total_credit = 0
    weights = 0
    for course in courses:
        total_credit += course_credits[course]
        weights += courses[course] * course_credits[course]
    
    return weights / total_credit

# %%
get_avg_gpa(get_semester_data(1), 0)
# Out:
# 3.1025641025641026

# %%
def get_grade_stats(semester_data, student):
    grade_list = []
    
    for course in semester_data[student]:
        grade = semester_data[student][course]
        grade_list.append(grade)
    
    mean = np.mean(grade_list)
    std_dev = np.std(grade_list)
    
    return mean, std_dev

# %%
# ~ mean ve std neyi hesapliyo bakilabilir
x = get_semester_data(1)
get_grade_stats(x, 0)
# Out:
# (2.875, 1.165922381636102)

# %%
def fit_cluster(train_sems, num_clusters, training_data, cluster_model):
    print("debug1")

    train_dataset = pd.DataFrame(columns=df.columns)
    
    # extracting instances from the dataset which should be in training data
    for sem in train_sems:
        train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)

    cluster_features = train_dataset[['GPA', 'Completed Credits'] + list(train_dataset.columns[9:])]
    
    # fitting a clustering model based on GPA, Completed Credits and Departments
    fitted_cluster_model = cluster_model(n_clusters=num_clusters).fit(cluster_features)
    print("debug2")
    cluster_labels = fitted_cluster_model.labels_
    
    cluster_dataset = {}   # splitting the train dataset into sub-dicts based on their predicted cluster label
    
    # assigning each students' data to their predicted clusters
    for i in range(len(cluster_labels)):
        cluster_dataset.setdefault(cluster_labels[i], {})
        student_number = train_dataset.iloc[i, 0]
        cluster_dataset[cluster_labels[i]][student_number] = training_data[student_number]
    
    return cluster_dataset, fitted_cluster_model

# %%
fit_cluster([1, 2, 3, 4], 15, x, KMeans)
# Out:
# debug1
# debug2
# /Users/ahmedsaidgulsen/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ({9: {0: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 1,
#     'Advanced Mathematics A(1)': 4,
#     'College English A(1)': 3,
#     'University Chinese': 1,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 3},
#    1: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 1,
#     'Advanced Mathematics A(1)': 4,
#     'College English A(1)': 3,
#     'University Chinese': 2,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 5},
#    12: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 2,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 3},
#    13: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 2,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 3},
#    14: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 2,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 3,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 3},
#    16: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 2,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 3},
#    23: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 4,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 3},
#    29: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 4,
#     'College English A(1)': 2,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 4},
#    38: {'Ideological and Moral Cultivation and Legal Foundation': 5,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 5,
#     'College English A(1)': 1,
#     'University Chinese': 1,
#     'Mental Health Education for College Students': 1,
#     'Ideological and Political Theory Course Practice1': 1},
#    48: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 4,
#     'College English A(1)': 2,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 5},
#    51: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 3,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 5},
#    55: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 2,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 5,
#     'Ideological and Political Theory Course Practice1': 3},
#    56: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 3,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 5},
#    60: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 2,
#     'Advanced Mathematics A(1)': 4,
#     'College English A(1)': 2,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 3},
#    66: {'Ideological and Moral Cultivation and Legal Foundation': 5,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 1,
#     'College English A(1)': 4,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 5},
#    70: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 5,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 2,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 5},
#    72: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 3,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 5,
#     'Ideological and Political Theory Course Practice1': 5},
#    77: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 2,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 3,
#     'University Chinese': 2,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 5},
#    78: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 2,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 5,
#     'Ideological and Political Theory Course Practice1': 5},
#    82: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 4,
#     'College English A(1)': 2,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 2},
#    84: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 5,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 4,
#     'College English A(1)': 2,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 2},
#    85: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 5,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 3,
#     'University Chinese': 2,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 2},
#    86: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 2,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 2},
#    91: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 5,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 4,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 2},
#    92: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 3,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 2},
#    99: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 5,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 4,
#     'University Chinese': 2,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 2},
#    104: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 4,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 2},
#    108: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 5,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 4,
#     'College English A(1)': 2,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 2},
#    112: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 4,
#     'College English A(1)': 2,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 2},
#    116: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 4,
#     'College English A(1)': 2,
#     'University Chinese': 2,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 2},
#    126: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 5,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 3,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 2},
#    129: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 5,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 3,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 2},
#    130: {'Ideological and Moral Cultivation and Legal Foundation': 2,
#     'Success: Career Planning': 5,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 3,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 5,
#     'Ideological and Political Theory Course Practice1': 2},
#    131: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 5,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 3,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 2},
#    135: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 5,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 1,
#     'College English A(1)': 4,
#     'University Chinese': 2,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 2},
#    139: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 5,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 2,
#     'University Chinese': 2,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 2},
#    141: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 5,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 2,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 5,
#     'Ideological and Political Theory Course Practice1': 2},
#    146: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 5,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 3,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 2},
#    149: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 4,
#     'College English A(1)': 2,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 2},
#    156: {'Ideological and Moral Cultivation and Legal Foundation': 5,
#     'Success: Career Planning': 5,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 3,
#     'University Chinese': 2,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 2},
#    163: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 5,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 4,
#     'University Chinese': 1,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 2},
#    167: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 3,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 2},
#    168: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 5,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 2,
#     'University Chinese': 1,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 2},
#    170: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 5,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 4,
#     'College English A(1)': 3,
#     'University Chinese': 2,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 2},
#    171: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 5,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 4,
#     'College English A(1)': 3,
#     'University Chinese': 1,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 2},
#    178: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 5,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 4,
#     'College English A(1)': 2,
#     'University Chinese': 1,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 2},
#    181: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 4,
#     'University Chinese': 2,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 2},
#    185: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 1,
#     'Introduction to Computer Science': 5,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 4,
#     'University Chinese': 1,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 2},
#    202: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 5,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 3,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 2},
#    207: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 5,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 3,
#     'University Chinese': 5,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 2},
#    215: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 5,
#     'Introduction to Computer Science': 2,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 3,
#     'University Chinese': 2,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 2},
#    220: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 2,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 3,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 5,
#     'Ideological and Political Theory Course Practice1': 2},
#    230: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 5,
#     'Introduction to Computer Science': 2,
#     'Advanced Mathematics A(1)': 4,
#     'College English A(1)': 3,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 2,
#     'Ideological and Political Theory Course Practice1': 2},
#    232: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 4,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 1,
#     'College English A(1)': 4,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 3},
#    235: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 4,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 3},
#    240: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 4,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 3},
#    242: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 3,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 5},
#    245: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 3,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 3},
#    247: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 5,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 3,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 5},
#    253: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 5,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 3,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 3},
#    254: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 3,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 3},
#    257: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 3,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 3},
#    259: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 1,
#     'College English A(1)': 4,
#     'University Chinese': 5,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 3},
#    260: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 5,
#     'Advanced Mathematics A(1)': 1,
#     'College English A(1)': 4,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 3},
#    261: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 3,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 3},
#    262: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 3,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 3},
#    263: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 5,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 2,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 3},
#    267: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 3,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 3},
#    268: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 1,
#     'College English A(1)': 4,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 5,
#     'Ideological and Political Theory Course Practice1': 3},
#    269: {'Ideological and Moral Cultivation and Legal Foundation': 5,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 1,
#     'College English A(1)': 3,
#     'University Chinese': 5,
#     'Mental Health Education for College Students': 5,
#     'Ideological and Political Theory Course Practice1': 5},
#    272: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 3,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 3},
#    278: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 5,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 3,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 3},
#    279: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 1,
#     'College English A(1)': 5,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 3},
#    280: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 5,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 4,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 5},
#    284: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 4,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 3},
#    286: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 4,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 1,
#     'College English A(1)': 3,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 5,
#     'Ideological and Political Theory Course Practice1': 3},
#    290: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 3,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 3},
#    291: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 2,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 3},
#    296: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 4,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 3},
#    297: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 4,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 5},
#    298: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 1,
#     'College English A(1)': 4,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 5},
#    303: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 4,
#     'College English A(1)': 2,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 3},
#    304: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 4,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 3},
#    306: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 3,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 3},
#    307: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 3,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 5},
#    308: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 5,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 1,
#     'College English A(1)': 3,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 5},
#    317: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 5,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 3},
#    326: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 4,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 3,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 4},
#    328: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 2,
#     'Introduction to Computer Science': 2,
#     'Advanced Mathematics A(1)': 4,
#     'College English A(1)': 3,
#     'University Chinese': 2,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 2},
#    329: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 2,
#     'Introduction to Computer Science': 2,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 4,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 3},
#    330: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 2,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 1,
#     'College English A(1)': 4,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 4},
#    335: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 5,
#     'Introduction to Computer Science': 2,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 2,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 2},
#    338: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 4,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 1,
#     'College English A(1)': 4,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 4},
#    341: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 2,
#     'Introduction to Computer Science': 2,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 3,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 2},
#    342: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 2,
#     'Introduction to Computer Science': 2,
#     'Advanced Mathematics A(1)': 4,
#     'College English A(1)': 2,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 2},
#    343: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 4,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 3,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 2},
#    349: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 4,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 1,
#     'College English A(1)': 3,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 4},
#    352: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 2,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 2,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 4},
#    355: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 4,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 1,
#     'College English A(1)': 4,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 4},
#    358: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 2,
#     'Introduction to Computer Science': 2,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 3,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 4},
#    362: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 2,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 2,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 4},
#    363: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 2,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 4,
#     'College English A(1)': 1,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 4},
#    364: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 5,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 1,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 4},
#    368: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 2,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 3,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 4},
#    373: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 2,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 1,
#     'College English A(1)': 4,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 4},
#    376: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 2,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 2,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 3},
#    378: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 3,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 4},
#    380: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 5,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 1,
#     'College English A(1)': 4,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 4}},
#   4: {2: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 2,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 3},
#    3: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 2,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 3},
#    7: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 3,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 4},
#    11: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 2,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 3},
#    15: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 1,
#     'College English A(1)': 2,
#     'University Chinese': 2,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 3},
#    17: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 1,
#     'College English A(1)': 2,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 5},
#    20: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 2,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 5},
#    30: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 2,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 4},
#    33: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 2,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 2,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 5},
#    34: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 2,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 5},
#    35: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 2,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 5},
#    37: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 2,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 2,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 5},
#    41: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 2,
#     'Advanced Mathematics A(1)': 1,
#     'College English A(1)': 4,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 5},
#    45: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 2,
#     'Advanced Mathematics A(1)': 1,
#     'College English A(1)': 3,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 5},
#    54: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 2,
#     'University Chinese': 2,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 5},
#    58: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 2,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 5},
#    79: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 2,
#     'Advanced Mathematics A(1)': 1,
#     'College English A(1)': 2,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 5},
#    96: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 1,
#     'College English A(1)': 3,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 2},
#    100: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 1,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 2},
#    101: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 5,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 1,
#     'College English A(1)': 1,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 2},
#    124: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 2,
#     'University Chinese': 2,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 2},
#    128: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 1,
#     'College English A(1)': 2,
#     'University Chinese': 1,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 2},
#    133: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 5,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 1,
#     'University Chinese': 2,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 2},
#    136: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 1,
#     'College English A(1)': 4,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 2},
#    138: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 5,
#     'Introduction to Computer Science': 5,
#     'Advanced Mathematics A(1)': 2,
# ...
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 3},
#    282: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 4,
#     'College English A(1)': 4,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 3},
#    283: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 4,
#     'University Chinese': 5,
#     'Mental Health Education for College Students': 5,
#     'Ideological and Political Theory Course Practice1': 3},
#    284: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 4,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 3},
#    285: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 4,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 3},
#    287: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 4,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 3,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 3},
#    288: {'Ideological and Moral Cultivation and Legal Foundation': 2,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 5,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 2,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 5,
#     'Ideological and Political Theory Course Practice1': 3},
#    290: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 3,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 3},
#    291: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 2,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 3},
#    292: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 5,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 4,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 5,
#     'Ideological and Political Theory Course Practice1': 5},
#    297: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 4,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 5},
#    298: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 1,
#     'College English A(1)': 4,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 5},
#    301: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 2,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 3},
#    303: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 4,
#     'College English A(1)': 2,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 3},
#    304: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 4,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 3},
#    310: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 5,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 1,
#     'College English A(1)': 4,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 3},
#    313: {'Ideological and Moral Cultivation and Legal Foundation': 5,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 2,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 3},
#    323: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 2,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 3},
#    324: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 3,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 3},
#    326: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 4,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 3,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 4},
#    328: {'Ideological and Moral Cultivation and Legal Foundation': 3,
#     'Success: Career Planning': 2,
#     'Introduction to Computer Science': 2,
#     'Advanced Mathematics A(1)': 4,
#     'College English A(1)': 3,
#     'University Chinese': 2,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 2},
#    330: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 2,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 1,
#     'College English A(1)': 4,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 4},
#    332: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 2,
#     'Introduction to Computer Science': 2,
#     'Advanced Mathematics A(1)': 4,
#     'College English A(1)': 3,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 4},
#    333: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 4,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 2},
#    334: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 2,
#     'Introduction to Computer Science': 2,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 4,
#     'University Chinese': 5,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 4},
#    335: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 5,
#     'Introduction to Computer Science': 2,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 2,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 2},
#    337: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 2,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 2,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 4},
#    341: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 2,
#     'Introduction to Computer Science': 2,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 3,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 2},
#    343: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 4,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 3,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 2},
#    345: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 4,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 3,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 2},
#    346: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 2,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 1,
#     'College English A(1)': 2,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 4},
#    347: {'Ideological and Moral Cultivation and Legal Foundation': 5,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 2,
#     'Advanced Mathematics A(1)': 4,
#     'College English A(1)': 3,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 4},
#    348: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 4,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 4,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 4},
#    349: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 4,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 1,
#     'College English A(1)': 3,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 4},
#    350: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 5,
#     'Introduction to Computer Science': 2,
#     'Advanced Mathematics A(1)': 2,
#     'College English A(1)': 2,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 4},
#    353: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 5,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 3,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 4},
#    355: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 4,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 1,
#     'College English A(1)': 4,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 4},
#    358: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 2,
#     'Introduction to Computer Science': 2,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 3,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 4},
#    359: {'Ideological and Moral Cultivation and Legal Foundation': 5,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 2,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 3,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 4},
#    361: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 2,
#     'Introduction to Computer Science': 2,
#     'Advanced Mathematics A(1)': 4,
#     'College English A(1)': 4,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 4},
#    363: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 2,
#     'Introduction to Computer Science': 4,
#     'Advanced Mathematics A(1)': 4,
#     'College English A(1)': 1,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 4},
#    366: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 2,
#     'Introduction to Computer Science': 2,
#     'Advanced Mathematics A(1)': 1,
#     'College English A(1)': 2,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 2},
#    368: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 2,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 3,
#     'University Chinese': 4,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 4},
#    376: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 2,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 2,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 4,
#     'Ideological and Political Theory Course Practice1': 3},
#    378: {'Ideological and Moral Cultivation and Legal Foundation': 4,
#     'Success: Career Planning': 3,
#     'Introduction to Computer Science': 3,
#     'Advanced Mathematics A(1)': 3,
#     'College English A(1)': 3,
#     'University Chinese': 3,
#     'Mental Health Education for College Students': 3,
#     'Ideological and Political Theory Course Practice1': 4}}},
#  KMeans(n_clusters=15))

# %%
def cluster_test_data(cluster_model, semester_num):
    # extracting all instances with the given semester_num from the main dataFrame
    test_dataset = df[df.iloc[:, 4] == semester_num]
    test_dataset.index = range(len(test_dataset))
    
    # predicting the cluster labels of test data using a cluster model fitted on the train data so far
    cluster_features = test_dataset[['GPA', 'Completed Credits'] + list(test_dataset.columns[9:])]
    cluster_labels = cluster_model.predict(cluster_features)
    
    # getting the semester data of available students in test semester
    semester_data = get_semester_data(semester_num)
    
    cluster_dataset = {}   # splitting the test dataset into sub-dicts based on their predicted cluster label
    
    # assigning each students' data to their predicted clusters
    for i in range(len(cluster_labels)):
        cluster_dataset.setdefault(cluster_labels[i], {})
        student_number = test_dataset.iloc[i, 0]
        cluster_dataset[cluster_labels[i]][student_number] = semester_data[student_number]
        
    return cluster_dataset

# %%
def get_errors(train_semester, test_semester, sim, item_based):
    average_gpa = {}
    y_true = []
    y_pred = []
    gpa = {}
    
    for student in train_semester:
        gpa[student] = get_avg_gpa(train_semester, student)
    
    item_sims = recommendations.calculateSimilarItems(train_semester)
    # predicting recommended courses for each student in training data
    for student in train_semester:
        recommended_courses = {}
        
        if item_based:
            recs = recommendations.getRecommendedItems(train_semester, item_sims, student)
        else:
            recs = recommendations.getRecommendations(train_semester, student, sim, dgpa=True, gpa=gpa, delta=0.7)
        
        for rec_grade, rec_course in recs:
            recommended_courses.setdefault(rec_course, rec_grade)
            
        average_gpa.setdefault(student, get_avg_gpa(train_semester, student))
        
        # skipping students from training data who do not have not taken courses in test data
        if student not in test_semester:
            continue
        
        mean, std_dev = get_grade_stats(train_semester, student)

       # checking for students' test data records in recommended courses
        for course_title in test_semester[student]:
            if course_title in recommended_courses:   # considering the predicted grade if course is available
                rec_grade = recommended_courses[course_title]
                if rec_grade < mean - (2 * std_dev) or rec_grade > mean + (2 * std_dev):
                    continue
                y_pred.append(rec_grade)
            else:   # considering the average GPA if course is not available in recommended courses
                rec_grade = average_gpa[student]
                if rec_grade < mean - (2 * std_dev) or rec_grade > mean + (2 * std_dev):
                    continue
                y_pred.append(rec_grade)
            y_true.append(test_semester[student][course_title])
            
    assert len(y_true) == len(y_pred)   
    return y_true, y_pred

# %%
def predict(sim, cluster_model, item_based=False):
    predictions = {} # storing error scores in a dict with shape: 
                      # {num_clusters (k=2,3,...,7): 
                        # {num_training_semesters (N=1,2,...,7): {'y_true': [], 'y_pred': []}, ...},
                      #...}
    
    sorted_semesters = sorted(set(df.iloc[:, 4]))   # sorting semesters in a time series manner
    for num_clusters in range(10, 31, 5):
        predictions.setdefault(str(num_clusters), {})
        train_semester = {}   # {student_number: {course_title: grade, ...}, ...}
        for sem_idx in range(1, len(sorted_semesters)):
            predictions[str(num_clusters)].setdefault(str(sem_idx), {'y_true': [], 'y_pred': []})
            
            # combining all previous semesters in dataset and consider it as training semester
            new_semester = get_semester_data(sorted_semesters[sem_idx-1])
            for student in new_semester:
                if student in train_semester:   # combine data if a student already exist
                    train_semester[student].update(new_semester[student])
                else:   # create a new key-value pair for students with no record
                    train_semester[student] = new_semester[student]
            
            training_semesters_name = sorted_semesters[:sem_idx]   # names of all training semesters
            # ~ print yaptik 
            print(training_semesters_name)
            
            # getting the cluster model fitted on training data and each clusters' training data
            train_cluster_data, fitted_cluster_model = fit_cluster(training_semesters_name, num_clusters, train_semester, cluster_model)
            
            # getting the clustered test data
            test_semester_name = sorted_semesters[sem_idx]
            test_cluster_data = cluster_test_data(fitted_cluster_model, test_semester_name)
            
            # fitting each cluster label with a similarity metric, and measure the error between the same
            # cluster labels in training and test data
            for cluster_label in train_cluster_data:
                if cluster_label not in test_cluster_data:
                    continue
                y_true, y_pred = get_errors(train_cluster_data[cluster_label], test_cluster_data[cluster_label], sim, item_based)
                predictions[str(num_clusters)][str(sem_idx)]['y_true'] += y_true
                predictions[str(num_clusters)][str(sem_idx)]['y_pred'] += y_pred
        
    return predictions

# %%
model_predictions = {}

# %%
predictions = predict(recommendations.sim_distance, KMeans)
model_predictions['Euclidean Distance'] = predictions
# Out:
# [1]
# debug1
# debug2
# /Users/ahmedsaidgulsen/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# [1, 2]
# debug1
# debug2
# /Users/ahmedsaidgulsen/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# [1, 2, 3]
# debug1
# debug2
# /Users/ahmedsaidgulsen/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# [1, 2, 3, 4]
# debug1
# debug2
# /Users/ahmedsaidgulsen/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# [1, 2, 3, 4, 5]
# debug1
# debug2
# /Users/ahmedsaidgulsen/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# [1, 2, 3, 4, 5, 6]
# debug1
# debug2
# /Users/ahmedsaidgulsen/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# [1]
# debug1
# debug2
# /Users/ahmedsaidgulsen/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# [1, 2]
# debug1
# debug2
# /Users/ahmedsaidgulsen/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# [1, 2, 3]
# debug1
# debug2
# /Users/ahmedsaidgulsen/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# [1, 2, 3, 4]
# debug1
# debug2
# /Users/ahmedsaidgulsen/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# [1, 2, 3, 4, 5]
# debug1
# debug2
# /Users/ahmedsaidgulsen/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# [1, 2, 3, 4, 5, 6]
# debug1
# debug2
# /Users/ahmedsaidgulsen/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# [1]
# debug1
# debug2
# /Users/ahmedsaidgulsen/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# [1, 2]
# debug1
# debug2
# /Users/ahmedsaidgulsen/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# [1, 2, 3]
# debug1
# /Users/ahmedsaidgulsen/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# debug2
# [1, 2, 3, 4]
# debug1
# debug2
# /Users/ahmedsaidgulsen/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# [1, 2, 3, 4, 5]
# debug1
# /Users/ahmedsaidgulsen/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# debug2
# [1, 2, 3, 4, 5, 6]
# debug1
# debug2
# /Users/ahmedsaidgulsen/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# [1]
# debug1
# debug2
# /Users/ahmedsaidgulsen/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# [1, 2]
# debug1
# debug2
# /Users/ahmedsaidgulsen/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# [1, 2, 3]
# debug1
# /Users/ahmedsaidgulsen/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# debug2
# [1, 2, 3, 4]
# debug1
# /Users/ahmedsaidgulsen/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# debug2
# [1, 2, 3, 4, 5]
# debug1
# /Users/ahmedsaidgulsen/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# debug2
# [1, 2, 3, 4, 5, 6]
# debug1
# /Users/ahmedsaidgulsen/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# debug2
# [1]
# debug1
# debug2
# /Users/ahmedsaidgulsen/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# [1, 2]
# debug1
# debug2
# /Users/ahmedsaidgulsen/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# [1, 2, 3]
# debug1
# /Users/ahmedsaidgulsen/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# debug2
# [1, 2, 3, 4]
# debug1
# /Users/ahmedsaidgulsen/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# debug2
# [1, 2, 3, 4, 5]
# debug1
# /Users/ahmedsaidgulsen/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# debug2
# [1, 2, 3, 4, 5, 6]
# debug1
# /Users/ahmedsaidgulsen/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# debug2

# %%
predictions = predict(recommendations.sim_jaccard, KMeans)
model_predictions['Jaccard Index'] = predictions
# Out:
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)

# %%
predictions = predict(recommendations.sim_pearson, KMeans)
model_predictions['Pearson Correlation'] = predictions
# Out:
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)
# C:\Users\casperrrr\AppData\Local\Temp\ipykernel_2212\2221448255.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   train_dataset = pd.concat([train_dataset, df[df.iloc[:, 4] == sem]], ignore_index=True)

# %%
with open('our_results.json', 'w') as fw:
    json.dump(model_predictions, fw, default=str)
